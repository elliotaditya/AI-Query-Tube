# %% [markdown]
# <a href="https://colab.research.google.com/github/Joshika-Mentor/AI-Query-Tube/blob/Aditya_Vish/Aditya_vish_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
from config import API_KEY, CHANNEL_ID

# %%
# %%writefile config.py
API_KEY = "AIzaSyAVOQhqmU-dXiFrwBdAk5t76qKyDjR8_mM"
CHANNEL_ID = "UCdEov4L0bpJ_h6W3sJxkfUA"
# Out:
# Overwriting config.py

# %%
url = "https://www.googleapis.com/youtube/v3/search"
params = {
    "key": API_KEY,
    "channelId": CHANNEL_ID,
    "part": "snippet,id",
    "order": "date",
    "maxResults": 50
}

response = requests.get(url, params=params).json()

videos = []
for item in response["items"]:
    if "videoId" in item["id"]:
        video_id = item["id"]["videoId"]
        title = item["snippet"]["title"]
        published = item["snippet"]["publishedAt"]
        videos.append([video_id, title, published])

df = pd.DataFrame(videos, columns=["video_id", "title", "published_date"])
df.head()
# Out:
#       video_id                                              title  \
# 0  rdT_cuR0Rrw  Vizz-AI Teaser launch | Your own personal AI t...
# 1  GA2BQ9vIBnE  Step‐by‐Step Nano VLM Workflow  #vizuara #nanovlm
# 2  Rt4oRES1QLM                   Introduction to Swin transformer
# 3  Yyir7-OAnlA  Lecture 2 - Variational Autoencoders Explained...
# 4  5sQnmK7zhcE  CLIP - The Paper Everyone Talks About #visiont...
#
#          published_date
# 0  2025-12-15T16:12:29Z
# 1  2025-12-13T12:19:57Z
# 2  2025-12-13T05:30:28Z
# 3  2025-12-10T06:30:17Z
# 4  2025-12-04T07:11:10Z

# %%
df.to_csv("youtube_metadata.csv", index=False)
